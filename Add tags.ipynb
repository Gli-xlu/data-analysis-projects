# %%
from apiclient.discovery import build
from oauth2client.service_account import ServiceAccountCredentials

def get_service(api_name, api_version, scopes, key_file_location):
    """Get a service that communicates to a Google API.

    Args:
        api_name: The name of the api to connect to.
        api_version: The api version to connect to.
        scopes: A list auth scopes to authorize for the application.
        key_file_location: The path to a valid service account JSON key file.

    Returns:
        A service that is connected to the specified API.
    """

    credentials = ServiceAccountCredentials.from_json_keyfile_name(
            key_file_location, scopes=scopes)

    # Build the service object.
    service = build(api_name, api_version, credentials=credentials)

    return service

def get_first_profile_id(service):
    # Use the Analytics service object to get the first profile id.

    # Get a list of all Google Analytics accounts for this user
    accounts = service.management().accounts().list().execute()

    if accounts.get('items'):
        # Get the first Google Analytics account.
        account = accounts.get('items')[0].get('id')

        # Get a list of all the properties for the first account.
        properties = service.management().webproperties().list(
                accountId=account).execute()

        if properties.get('items'):
            # Get the first property id.
            property = properties.get('items')[0].get('id')

            # Get a list of all views (profiles) for the first property.
            profiles = service.management().profiles().list(
                    accountId=account,
                    webPropertyId=property).execute()

            if profiles.get('items'):
                # return the first view (profile) id.
                return profiles.get('items')[0].get('id')

    return None

def get_results(service, profile_id):
    # Use the Analytics Service Object to query the Core Reporting API
    # for the number of sessions within the past seven days.
    return service.data().ga().get(
            ids='ga:' + profile_id,
            start_date='7daysAgo',
            end_date='today',
            metrics='ga:sessions').execute()

def print_results(results):
    # Print data nicely for the user.
    if results:
        print('View (Profile):', results.get('profileInfo').get('profileName'))
        print('Total Sessions:', results.get('rows')[0][0])

    else:
        print('No results found')

def main():
    # Define the auth scopes to request.
    scope = 'https://www.googleapis.com/auth/analytics.readonly'
    key_file_location = r'C:\Users\HP\Downloads\My Project-c4f6ea37d1ef.json'

    # Authenticate and construct service.
    service = get_service(
            api_name='analytics',
            api_version='v3',
            scopes=[scope],
            key_file_location=key_file_location)

    profile_id = get_first_profile_id(service)
    print_results(get_results(service, profile_id))

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-10-4b15c2dd689f> in <module>
#      86
#      87 if __name__ == '__main__':
# ---> 88     main()
#
# <ipython-input-10-4b15c2dd689f> in main()
#      82             key_file_location=key_file_location)
#      83
# ---> 84     profile_id = get_first_profile_id(service)
#      85     print_results(get_results(service, profile_id))
#      86
#
# <ipython-input-10-4b15c2dd689f> in get_first_profile_id(service)
#      27
#      28     # Get a list of all Google Analytics accounts for this user
# ---> 29     accounts = service.management().accounts().list().execute()
#      30
#      31     if accounts.get('items'):
#
# ~\Anaconda3\envs\Crypta\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     128                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
# ...

# %%
urls = op.load_workbook(r'C:\Users\HP\Notebooks\Семестр2\Проект\urls.xlsx');

sheet = urls.get_sheet_by_name('Sheet1');
from itertools import islice
data = sheet.values
cols = next(data)[1:]
data = list(data)
idx = [r[0] for r in data]
data = (islice(r, 1, None) for r in data)
urls = pd.DataFrame(data, index=idx, columns=cols)

yandex1 = op.load_workbook(r'C:\Users\HP\Notebooks\Семестр2\Проект\yandex_urls.xlsx');

sheet = yandex1.get_sheet_by_name('Sheet1');
from itertools import islice
data = sheet.values
cols = next(data)[1:]
data = list(data)
idx = [r[0] for r in data]
data = (islice(r, 1, None) for r in data)
yandex1 = pd.DataFrame(data, index=idx, columns=cols)

yandex2 = op.load_workbook(r'C:\Users\HP\Notebooks\Семестр2\Проект\yandex_urls10-19.xlsx');

sheet = yandex2.get_sheet_by_name('Sheet1');
from itertools import islice
data = sheet.values
cols = next(data)[1:]
data = list(data)
idx = [r[0] for r in data]
data = (islice(r, 1, None) for r in data)
yandex2 = pd.DataFrame(data, index=idx, columns=cols)

yandex3 = op.load_workbook(r'C:\Users\HP\Notebooks\Семестр2\Проект\yandex_urls20.xlsx');

sheet = yandex3.get_sheet_by_name('Sheet1');
from itertools import islice
data = sheet.values
cols = next(data)[1:]
data = list(data)
idx = [r[0] for r in data]
data = (islice(r, 1, None) for r in data)
yandex3 = pd.DataFrame(data, index=idx, columns=cols)
# Out:
# C:\Users\HP\Anaconda3\envs\Crypta\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\HP\Anaconda3\envs\Crypta\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#
# C:\Users\HP\Anaconda3\envs\Crypta\lib\site-packages\ipykernel_launcher.py:25: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
# C:\Users\HP\Anaconda3\envs\Crypta\lib\site-packages\ipykernel_launcher.py:36: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).

# %%
frames = [urls, yandex1, yandex2, yandex3]
Frame = pd.concat(frames, ignore_index=True)
Frame
# Out:
#      Search Engine  IDRequest  \
# 0           Google          0
# 1           Google          0
# 2           Google          0
# 3           Google          0
# 4           Google          0
# ...            ...        ...
# 1305        Yandex         21
# 1306        Yandex         21
# 1307        Yandex         21
# 1308        Yandex         21
# 1309        Yandex         21
#
#                                                URL page
# 0     https://www.google.com/imgres?imgurl=https://u...
# 1     https://www.google.com/imgres?imgurl=http://az...
# 2     https://www.google.com/imgres?imgurl=https://g...
# 3     https://www.google.com/imgres?imgurl=https://i...
# 4     https://www.google.com/url?q=https://ru.wikipe...
# ...                                                 ...
# 1305          https://poemata.ru/poets/kamenev-gavriil/
# 1306  https://wpoet.ru/%D1%80%D0%BE%D1%81%D1%81%D0%B...
# 1307            https://45ll.net/gavriil_kamenev/stihi/
# ...

# %% [markdown]
# * биография: родился, дата рождения, место смерти, умер, 1773 - 1803, 1772 - 1803, напечатан, образование, много ссылок?
# * отсеивание - владимир, зиновий, Михаил Польский
# * произведения - Аннотация, стихотворения,  количество р

# %%
import pandas as pd;
import openpyxl as op;

# %%
urls = op.load_workbook(r'C:\Users\HP\Notebooks\Семестр2\Проект\all_urls.xlsx');
sheet = urls.get_sheet_by_name('Sheet1');
from itertools import islice
data = sheet.values
cols = next(data)[1:]
data = list(data)
idx = [r[0] for r in data]
data = (islice(r, 1, None) for r in data)
df = pd.DataFrame(data, index=idx, columns=cols)
# Out:
# C:\Users\HP\Anaconda3\envs\Crypta\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).

# %%
df.head()
# Out:
#   Search Engine  IDRequest                                           URL page
# 0        Google          0  https://www.google.com/imgres?imgurl=https://u...
# 1        Google          0  https://www.google.com/imgres?imgurl=http://az...
# 2        Google          0  https://www.google.com/imgres?imgurl=https://g...
# 3        Google          0  https://www.google.com/imgres?imgurl=https://i...
# 4        Google          0  https://www.google.com/url?q=https://ru.wikipe...

# %%
df['Status_code'] = -1
df['p'] = None
df['title'] = None
df['h1'] = None
df['h2'] = None
df['li'] = None
df['em'] = None
df['dd'] = None
df['pre'] = None
df['plaintext'] = None
df['b'] = None
df['blockquote'] = None
df['abbr'] = None
df['acronym'] = None
df['address'] = None
df['cite'] = None
df['ruby'] = None
df['rp'] = None

# %%
df.head()
# Out:
#   Search Engine  IDRequest                                           URL page  \
# 0        Google          0  https://www.google.com/imgres?imgurl=https://u...
# 1        Google          0  https://www.google.com/imgres?imgurl=http://az...
# 2        Google          0  https://www.google.com/imgres?imgurl=https://g...
# 3        Google          0  https://www.google.com/imgres?imgurl=https://i...
# 4        Google          0  https://www.google.com/url?q=https://ru.wikipe...
#
#    Status_code     p title    h1    h2    li    em  ...   pre plaintext     b  \
# 0           -1  None  None  None  None  None  None  ...  None      None  None
# 1           -1  None  None  None  None  None  None  ...  None      None  None
# 2           -1  None  None  None  None  None  None  ...  None      None  None
# 3           -1  None  None  None  None  None  None  ...  None      None  None
# 4           -1  None  None  None  None  None  None  ...  None      None  None
#
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
def getTagText(tag, soup):
    str = ""
    tags = soup.find_all(tag)
    for elem in tags:
        str = "{0}\n{1}".format(str, elem.getText())
    return str

# %%
def getInformation(url, index, df):
    page = requests.get(url) 
    soup = BeautifulSoup(page.text)
    df[:index]['Status_code'] = page.status_code
    if(page.status_code != 200):
        return
    df['title'][index] = soup.find('title').getText()
    df['p'][index] = getTagText('p', soup)
    df['h1'][index] = getTagText('h1', soup)
    df['h2'][index] = getTagText('h2', soup)
    df['li'][index] = getTagText('li', soup)
    df['em'][index] = getTagText('em', soup)
    df['dd'][index] = getTagText('dd', soup)
    df['plaintext'][index] = getTagText('plaintext', soup)
    df['pre'][index] = getTagText('pre', soup)
    df['b'][index] = getTagText('b', soup)
    df['blockquote'][index] = getTagText('blockquote', soup)
    df['abbr'][index] = getTagText('abbr', soup)
    df['acronym'][index] = getTagText('acronym', soup)
    df['address'][index] = getTagText('address', soup)
    df['cite'][index] = getTagText('cite', soup)
    df['ruby'][index] = getTagText('ruby', soup)
    df['rp'][index] = getTagText('rp', soup)
    return df

# %% [markdown]
# # 1

# %%
df.to_excel('tags.xlsx')

# %%
url = df['URL page'][4]
print(url)
page = requests.get(url) 
soup = BeautifulSoup(page.text)
# Out:
# https://www.google.com/url?q=https://ru.wikipedia.org/wiki/%25D0%259A%25D0%25B0%25D0%25BC%25D0%25B5%25D0%25BD%25D0%25B5%25D0%25B2,_%25D0%2593%25D0%25B0%25D0%25B2%25D1%2580%25D0%25B8%25D0%25B8%25D0%25BB_%25D0%259F%25D0%25B5%25D1%2582%25D1%2580%25D0%25BE%25D0%25B2%25D0%25B8%25D1%2587&sa=U&ved=2ahUKEwjOsbD5s97nAhXjwMQBHR6DDA0QmhMwB3oECAoQDg&usg=AOvVaw3n_laSm7BGCJ2CmIKn7vgK

# %%
page.status_code
# Out:
# 200

# %%
soup.find('title').getText()
# Out:
# 'Каменев, Гавриил Петрович — Википедия'

# %%
p = soup.find_all('p')
for elem in p:
    print(elem.getText())
# Out:
# Гаврии́л (Гаври́ла) Петро́вич Ка́менев (1773, Казань — 1803, Казань) — русский поэт, прозаик, переводчик, бургомистр в Казани (1798—1800). Первый представитель русского романтизма[3]. Сделав
# поэзию «выразительницей собственного эмоционального опыта, он пользовался новой стихотворной формой — „германской“, лишённой рифм, и находился под сильным влиянием Оссиана и Юнга»[3].
#
# Родился в Казани в старинной и богатой купеческой семье. Его предком был казанский татарин-мурза Макул. Вскоре после захвата Иваном Грозным, Макула перешел к нему на службу и принял православие.
#
# ...

# %%
soup.find_all('pre')
# Out:
# []

# %%
soup.find_all('dd')
# Out:
# []

# %%
h2 = soup.find_all('h2')
for elem in h2:
    print(elem.getText())
# Out:
# Содержание
# Происхождение[править | править код]
# Литературная деятельность[править | править код]
# Общественная деятельность[править | править код]
# Смерть[править | править код]
# Семья[править | править код]
# Источники[править | править код]
# Литература[править | править код]
# Ссылки[править | править код]
# Навигация

# %%
p = soup.find_all('h1')
for elem in p:
    print(elem.getText())
# Out:
# Гавриил Петрович Каменев

# %%
soup.find_all('em')
# Out:
# []

# %% [markdown]
# # 2

# %%
url = google_urls[15]
print(url)
page = requests.get(url) 
soup = BeautifulSoup(page.text)
# Out:
# https://www.google.com/url?q=http://az.lib.ru/k/kamenew_g_p/text_0020.shtml&sa=U&ved=2ahUKEwjOsbD5s97nAhXjwMQBHR6DDA0QFjAOegQIBhAB&usg=AOvVaw3QMRNqZVI5UkNah4KszTLt

# %%
print('Title: ', soup.find('title').getText())
# Out:
# Title:  Lib.ru/Классика: Каменев Гавриил Петрович. Стихотворения

# %%
p = soup.find_all('p')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('h2')
for elem in p:
    print(elem.getText())
# Out:
# Каменев Гавриил Петрович
# Стихотворения

# %%
p = soup.find_all('pre')
for elem in p:
    print(elem.getText())
# Out:
#                                Г. П. Каменев
#
#                                Стихотворения
#
# ----------------------------------------------------------------------------
#      Поэты-радищевцы
#      Серия "Библиотека поэта". Большая серия. Второе издание.
#      Вступительная статья, биографические справки, составление и  подготовка
# текста П. А. Орлова
#      Примечания П. А. Орлова и Г. А. Лихоткина
# ----------------------------------------------------------------------------
#
#                                  СОДЕРЖАНИЕ
#
#      Биографическая справка
#      261. Мечта
#      262. К П.С.Л.Р.
#      263. Малиновка
#      264. Старик
#      265. Мысли пьяного астронома (Из Клейста)
#      266. Утренняя песнь (Из Геснера)
#      267. К Пленире
#      268. Кладбище
#      269-270.
#      1. "Вечер любезный! вечер багряный..."
#      2. "Бури свирепством роза погибла..."
#      271. Желание спокойствия (Из соч. Г. Клейста)
#      272. Expromtum (С немецкого)
# ...

# %%
p = soup.find_all('em')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('dd')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('h1')
for elem in p:
    print(elem.getText())
# Out:
# Гавриил Петрович Каменев

# %% [markdown]
# # 3

# %%
url = google_urls[17]
print(url)
page = requests.get(url) 
soup = BeautifulSoup(page.text)
# Out:
# https://www.google.com/url?q=https://godliteratury.ru/projects/gavriil-kamenev-pozabyt-ya-vsey-vsele&sa=U&ved=2ahUKEwjOsbD5s97nAhXjwMQBHR6DDA0QFjAQegQICBAB&usg=AOvVaw2P3pEyM-YAYiZ4JD7dCyEP

# %%
soup.find('title').getText()
# Out:
# 'Гавриил Каменев. «Позабыт я всей вселенной» «  Год Литературы'

# %%
p = soup.find_all('p')
for elem in p:
    print(elem.getText())
# Out:
# Почему предтеча русских романтиков Гавриил Каменев оказался на «литературном кладбище»
#
# Текст: Олег Корякин, Казань
# Фото: wikipedia.org
# 20 марта исполнилось 245 лет со дня рождения казанского поэта Гавриила Каменева (1773—1803). Личность эта яркая и трагическая. Представитель богатого купеческого рода, бургомистр Казани, известный литератор своего времени, сгоревший от чахотки в 30 лет.
# Пушкин считал, что он «первый в России осмелился отступить от классицизма», и призывал русских романтиков «принести должную дань его памяти». Но Каменев, как это часто бывает с первопроходцами, оказался в забвении.
# Надгробие Каменева на кладбище Кизического монастыря. Конец XIX в.
# ...

# %%
p = soup.find_all('h2')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('em')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('pre')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('h1')
for elem in p:
    print(elem.getText())
# Out:
# Гавриил Петрович Каменев

# %%
p = soup.find_all('dd')
for elem in p:
    print(elem.getText())

# %% [markdown]
# # 4

# %%
url = google_urls[18]
print(url)
page = requests.get(url) 
soup = BeautifulSoup(page.text)
# Out:
# https://www.google.com/url?q=https://ru.wikisource.org/wiki/%25D0%2593%25D0%25B0%25D0%25B2%25D1%2580%25D0%25B8%25D0%25B8%25D0%25BB_%25D0%259F%25D0%25B5%25D1%2582%25D1%2580%25D0%25BE%25D0%25B2%25D0%25B8%25D1%2587_%25D0%259A%25D0%25B0%25D0%25BC%25D0%25B5%25D0%25BD%25D0%25B5%25D0%25B2&sa=U&ved=2ahUKEwjOsbD5s97nAhXjwMQBHR6DDA0QFjARegQIBBAB&usg=AOvVaw2aQWADWbi6U58n8bXeGSwM

# %%
soup.find('title').getText()
# Out:
# 'Гавриил Петрович Каменев — Викитека'

# %%
p = soup.find_all('p')
for elem in p:
    print(elem.getText())
# Out:
# Каменев, Гавриил Петрович
#
# ...

# %%
p = soup.find_all('h2')
for elem in p:
    print(elem.getText())
# Out:
# Поэзия[править]
# Ссылки[править]
# Навигация

# %%
p = soup.find_all('pre')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('em')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('dd')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('h1')
for elem in p:
    print(elem.getText())
# Out:
# Гавриил Петрович Каменев

# %% [markdown]
# # 5

# %%
url = google_urls[19]
print(url)
page = requests.get(url) 
soup = BeautifulSoup(page.text)
# Out:
# https://www.google.com/url?q=https://w.histrf.ru/articles/article/show/kamieniev_gavriil_pietrovich&sa=U&ved=2ahUKEwjOsbD5s97nAhXjwMQBHR6DDA0QFjASegQIAxAB&usg=AOvVaw2o24WRcZJ0LDUnjF76n9r1

# %%
soup.find('title').getText()
# Out:
# '            КАМЕНЕВ ГАВРИИЛ ПЕТРОВИЧ — информация на портале Энциклопедия Всемирная история\n    '

# %%
p = soup.find_all('h1')
for elem in p:
    print(elem.getText())
# Out:
# КАМЕНЕВ ГАВРИИЛ ПЕТРОВИЧ

# %%
p = soup.find_all('h2')
for elem in p:
    print(elem.getText())
# Out:
# Приглашаем историков внести свой вклад в Энциклопедию!

# %%
p = soup.find_all('p')
for elem in p:
    print(elem.getText())
# Out:
# Энциклопедия
#
#
#
# КАМЕНЕВ ГАВРИИЛ ПЕТРОВИЧ - русский поэт, прозаик.
# Сын куп­ца 1-й гиль­дии. Учил­ся в ча­ст­ном немецком пан­сио­не, вхо­дил в ка­зан­ский литературный кру­жок ма­со­на С. А. Мос­ко­тиль­ни­ко­ва. В 1799-1802 годах три­ж­ды вы­ез­жал в Мо­ск­ву и Санкт-Пе­тер­бург, где сбли­зил­ся с из­вест­ны­ми ма­со­нами (И. В. Ло­пу­хин, И. П. Тур­ге­нев) и ли­те­ра­то­ра­ми (Н. М. Ка­рам­зин и др.). В 1802 году, по­се­тив Санкт-Пе­тер­бург, стал чле­ном Воль­но­го об­ще­ст­ва лю­би­те­лей сло­вес­но­сти, на­ук и ху­до­жеств. Пе­ча­тал­ся в жур­на­лах «Му­за» (1796 год), «Ип­пок­ре­на» (1799-1801 годы), «Но­во­сти рус­ской ли­те­ра­ту­ры» (1802 год). В 1800-1802 годах из­дал 4 кни­ги со свои­ми пе­ре­во­да­ми по­вес­тей А. Ко­це­бу и К. Г. Шпи­са.
# ...

# %%
p = soup.find_all('pre')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('dd')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('em')
for elem in p:
    print(elem.getText())

# %% [markdown]
# # 6

# %%
url = google_urls[20]
print(url)
page = requests.get(url) 
soup = BeautifulSoup(page.text)
# Out:
# https://www.google.com/url?q=http://www.iske-kazan.ru/izvestnye-lyudi/247-gavriil-petrovich-kamenev-v-kazani&sa=U&ved=2ahUKEwjOsbD5s97nAhXjwMQBHR6DDA0QFjATegQIBRAB&usg=AOvVaw0Cyj5XKrbz8YoPDbMYPpmy

# %%
soup.find('title').getText()
# Out:
# 'Гавриил Петрович Каменев в Казани - Старая Казань'

# %%
p = soup.find_all('h1')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('h2')
for elem in p:
    print(elem.getText())
# Out:
# 				Гавриил Петрович Каменев в Казани
# О непознанном в жизни и  смерти нашего знаменитого земляка
# Хижицы 1803[го] Года июня 11[го] числа
# Newer news items:
# Older news items:

# %%
p = soup.find_all('p')
for elem in p:
    print(elem.getText())
# Out:
# Печаль следит за мной как тень...
# Казань - средоточие и магнит татарской культуры,в том числе литературного творчества, - не миновалиочень многие русские писатели. Ряд имен внушительный,среди них есть блистательные: Державин, Каменев, Аксаков,Боратынский, Горький, Заболоцкий, Тушнова...А еще - Пушкин, Маяковский, еще - Чистополь и Елабугасороковых... Одни в Казани родились либо жили,были укоренены, другие недолго ходили по казанскиммостовым, но оставили здесь заметный след.Любой подлинный писатель, художник вообще -духовный центр каждого пласта истории. Связуя воедино времена,творец сохраняет свою эпоху от забвения,продолжаясь в созидании исторической памяти.Начиная публикацию статей о литераторах, так или иначесвязанных с казанской землей, перелистаем страницыпрошлого - и вновь обретет жизнь витающий в закоулкахпамяти нетленный дух...
#
# ...

# %%
p = soup.find_all('pre')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('em')
for elem in p:
    print(elem.getText())
# Out:
# Печаль следит за мной как тень...
# О непознанном в жизни и  смерти нашего знаменитого земляка
# Казань - средоточие и магнит татарской культуры,
# в том числе литературного творчества, - не миновали
# очень многие русские писатели. Ряд имен внушительный,
# среди них есть блистательные: Державин, Каменев, Аксаков,
# Боратынский, Горький, Заболоцкий, Тушнова...
# А еще - Пушкин, Маяковский, еще - Чистополь и Елабуга
# сороковых... Одни в Казани родились либо жили,
# были укоренены, другие недолго ходили по казанским
# мостовым, но оставили здесь заметный след.
# Любой подлинный писатель, художник вообще -
# духовный центр каждого пласта истории. Связуя воедино времена,
# творец сохраняет свою эпоху от забвения,
# продолжаясь в созидании исторической памяти.
# Начиная публикацию статей о литераторах, так или иначе
# связанных с казанской землей, перелистаем страницы
# прошлого - и вновь обретет жизнь витающий в закоулках
# памяти нетленный дух...

# %%
p = soup.find_all('dd')
for elem in p:
    print(elem.getText())
# Out:
# 					Опубликовано: 07 Июнь 2015

# %% [markdown]
# # 7

# %%
url = google_urls[21]
print(url)
page = requests.get(url) 
soup = BeautifulSoup(page.text)
# Out:
# https://www.google.com/url?q=http://www.kznportal.ru/o_gorode/nazvaniya_ulits/k/id5038/&sa=U&ved=2ahUKEwjOsbD5s97nAhXjwMQBHR6DDA0QFjAUegQIARAB&usg=AOvVaw0Iw5TNTqQ7dqQozHCX5JKR

# %%
soup.find('title').getText()
# Out:
# 'Улица Поэта Каменева'

# %%
p = soup.find_all('h1')
for elem in p:
    print(elem.getText())
# Out:
# Улица Поэта Каменева

# %%
p = soup.find_all('h2')
for elem in p:
    print(elem.getText())
# Out:
# Каменев Гаврил Петрович

# %%
p = soup.find_all('p')
for elem in p:
    print(elem.getText())
# Out:
# Каменев Гаврил Петрович (1772-1803), казанский поэт, один из первых представителей раннего русского романтизма. Г.П. Каменев родился 3 февраля 1772 г. в Казани. Его отец, купец П.Г. Каменев, происходил из татарского княжеского рода Макуловых.
# ...

# %%
p = soup.find_all('pre')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('em')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('dd')
for elem in p:
    print(elem.getText())

# %% [markdown]
# # 8

# %%
url = google_urls[22]
print(url)
page = requests.get(url) 
soup = BeautifulSoup(page.text)
# Out:
# https://www.google.com/url?q=http://www.museum.ru/n14943&sa=U&ved=2ahUKEwjOsbD5s97nAhXjwMQBHR6DDA0QFjAVegQIAhAB&usg=AOvVaw20Tt8mhJIG-4GS--YNmqDl

# %%
soup.find('title').getText()
# Out:
# 'Диалог поэтов в культурном пространстве Казани'

# %%
p = soup.find_all('h1')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('h2')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('p')
for elem in p:
    print(elem.getText())
# Out:
# Организаторы - Национальный музей РТ, Музей Е.А. Боратынского, Казанский государственный университет (отделение журналистики).
# ...

# %%
p = soup.find_all('pre')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('em')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('dd')
for elem in p:
    print(elem.getText())

# %% [markdown]
# # 9

# %%
url = google_urls[23]
print(url)
page = requests.get(url) 
soup = BeautifulSoup(page.text)
# Out:
# https://www.google.com/url?q=http://history-kazan.ru/kazan-vchera-segodnya-zavtra/istoriya-v-litsakh/zhzl-kazanskaya-seriya/16851-geroj-svoego-vremeni-poet-gavriil-kamenev&sa=U&ved=2ahUKEwjOsbD5s97nAhXjwMQBHR6DDA0QFjAWegQIABAB&usg=AOvVaw0AZf4OirmAQHhLeB6zCGGT

# %%
soup.find('title').getText()
# Out:
# 'Герой своего времени поэт Гавриил Каменев'

# %%
p = soup.find_all('h1')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('h2')
for elem in p:
    print(elem.getText())
# Out:
# 		Герой своего времени поэт Гавриил Каменев

# %%
p = soup.find_all('p')
for elem in p:
    print(elem.getText())
# Out:
# Цитата
# Сей город, бесспорно, первый в России после Москвы, а Тверь – лучший после Петербурга; во всем видно, что Казань столица большого царства. По всей дороге прием мне был весьма ласковый и одинаковый, только здесь еще кажется градусом выше, по причине редкости для них видеть. Однако же с Ярославом, Нижним и Казанью да сбудется французская пословица, что от господского взгляду лошади разжиреют: вы уже узнаете в сенате, что я для сих городов сделала распоряжение
# Письмо А. В. ОлсуфьевуЕКАТЕРИНА II И КАЗАНЬ
# Хронограф
# 1940 – Родился Виктор Кронидович Федотов, живописец, заслуженный деятель искусств РТ, народный художник РТ
# 1809 – По указанию императора Александра I от 2 (15) марта в Казани вместо лазарета на 240 коек учрежден особый военный госпиталь на 300 больных.
#
# Фотогалерея
# ...

# %%
p = soup.find_all('em')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('pre')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('dd')
for elem in p:
    print(elem.getText())
# Out:
# 	09 сентября 2009 года

# %% [markdown]
# # 10

# %%
url = google_urls[27]
print(url)
page = requests.get(url) 
soup = BeautifulSoup(page.text)
# Out:
# http://enc-dic.com/enc_lit/Kamenev-g-p-2188.html

# %%
soup.find('title').getText()
# Out:
# 'Каменев Г. П. — Литературная энциклопедия'

# %%
p = soup.find_all('h1')
for elem in p:
    print(elem.getText())
# Out:
# Каменев Г. П.

# %%
p = soup.find_all('h2')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('p')
for elem in p:
    print(elem.getText())
# Out:
# КАМЕНЕВ Гавриил Петрович (1772—1803) — поэт. Р. в купеческой семье. К. получил лит-ое образование и был хорошо знаком с образцами немецкой поэзии. По смерти К. в «Периодическом издании» (1804) Вольного о-ва любителей словесности, наук и художеств, членом к-рого К. состоял, был впервые напечатан «Громвал». Существует 4 печатных редакции «Громвала»; общепринятая (Жуковского) — обработка предыдущих. «Громвал» был воспринят как «рыцарская», или «богатырская повесть». Он оригинален в смысле применения дактило-анапестического размера (жанровых признаков «баллады» в «Громвале» нет). Поэзия К. характерна для торговой буржуазной интеллигенции конца XVIII в.
# Библиография: I. Собр. сочин. подготовляется проф. Е. А. Бобровым; Список сочин. Каменева см. Бобров В. А., К биографии Г. П. Каменева, «Варшавские университетские известия», 1905, или отд., Варшава, 1905.
# ...

# %%
p = soup.find_all('pre')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('em')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('dd')
for elem in p:
    print(elem.getText())

# %% [markdown]
# # 11

# %%
url = google_urls[27]
print(url)
page = requests.get(url) 
soup = BeautifulSoup(page.text) 
soup.find('title').getText()
# Out:
# http://enc-dic.com/enc_lit/Kamenev-g-p-2188.html
# 'Каменев Г. П. — Литературная энциклопедия'

# %%
p = soup.find_all('h1')
for elem in p:
    print(elem.getText())
# Out:
# Каменев Г. П.

# %%
p = soup.find_all('h2')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('p')
for elem in p:
    print(elem.getText())
# Out:
# КАМЕНЕВ Гавриил Петрович (1772—1803) — поэт. Р. в купеческой семье. К. получил лит-ое образование и был хорошо знаком с образцами немецкой поэзии. По смерти К. в «Периодическом издании» (1804) Вольного о-ва любителей словесности, наук и художеств, членом к-рого К. состоял, был впервые напечатан «Громвал». Существует 4 печатных редакции «Громвала»; общепринятая (Жуковского) — обработка предыдущих. «Громвал» был воспринят как «рыцарская», или «богатырская повесть». Он оригинален в смысле применения дактило-анапестического размера (жанровых признаков «баллады» в «Громвале» нет). Поэзия К. характерна для торговой буржуазной интеллигенции конца XVIII в.
# Библиография: I. Собр. сочин. подготовляется проф. Е. А. Бобровым; Список сочин. Каменева см. Бобров В. А., К биографии Г. П. Каменева, «Варшавские университетские известия», 1905, или отд., Варшава, 1905.
# ...

# %%
p = soup.find_all('pre')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('em')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('dd')
for elem in p:
    print(elem.getText())

# %% [markdown]
# # 12

# %%
url = google_urls[28]
print(url)
page = requests.get(url) 
soup = BeautifulSoup(page.text) 
soup.find('title').getText()
# Out:
# http://cultcalend.ru/event/385/
# 'Этот домен припаркован компанией Timeweb'

# %%
p = soup.find_all('h1')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('h2')
for elem in p:
    print(elem.getText())
# Out:
# Виртуальный хостинг
# VDS
# Выделенные серверы

# %%
p = soup.find_all('p')
for elem in p:
    print(elem.getText())
# Out:
# Больше, чем хостинг.

# %% [markdown]
# # 13

# %%
url = google_urls[29]
print(url)
page = requests.get(url) 
print(page.encoding)
page.encoding = 'cp1251'
soup = BeautifulSoup(page.text) 
soup.find('title').getText()
# Out:
# http://www.jerusalem-korczak-home.com/bib/kamenev/polsky.html
# ISO-8859-1
# 'Михаил Польский представляет новый сборник стихов „ЖИЗНЬ ОДНА“'

# %%
p = soup.find_all('h1')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('h2')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('p')
for elem in p:
    print(elem.getText())
# Out:
# <<На главную сайта
#
#
# БИБЛИОТЕКА
# ЗАВТРАШНЕЙ
# КНИГИ
#
# Михаил Польский
#
# (Зиновий Каменев)
#
#
#
# ОГЛАВЛЕНИЕ
#
#
#
# СБОРНИК
#  "ЖИЗНЬ ОДНА (1988-2003)"
#
#
# Новые стихотворения, появившиеся после сборника
# Цикл Урок в
# студии "Корчак"
# Переводы из Ури-Цви Гринберга
# Переводы из Аделины Кляйн
#
#
# ПЕРЕВОДЫ С ИВРИТА ДЛЯ ДЕТЕЙ
# Переводы с русского на иврит
#
# Страница Михаила Польского на сайте Стихи.ру
#
#
# Напишите автору!
#
#
# К оглавлению раздела "Библиотека завтрашней
# книги"
#
# ЖИЗНЬ ОДНА*
#
# стихотворения 1988-2003
#
# Моей маме Маре-Этель
#  посвящаю эту книжку
# "АРБАТСТВО,
# РАСТВОРЕННОЕ В КРОВИ"
#
#
# Я
# тоже бродил и бредил Арбатом, когда великая антиоктябрьская революция
# свершилась, и новые ломкие песни вырвались из раскрепощенного горла…
# Там среди встрепанных неформалов вырос из прошлого кровавого абсурда
# советской истории странный гибрид-псевдоним Зиновий Каменев - "поэт
# ...

# %%
p = soup.find_all('pre')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('em')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('dd')
for elem in p:
    print(elem.getText())

# %% [markdown]
# # 14

# %%
url = google_urls[30]
print(url)
page = requests.get(url) 
print(page.encoding)
soup = BeautifulSoup(page.text) 
soup.find('title').getText()
# Out:
# http://www.kznportal.ru/o_gorode/nazvaniya_ulits/k/id5038/
# windows-1251
# 'Улица Поэта Каменева'

# %%
p = soup.find_all('h1')
for elem in p:
    print(elem.getText())
# Out:
# Улица Поэта Каменева

# %%
p = soup.find_all('h2')
for elem in p:
    print(elem.getText())
# Out:
# Каменев Гаврил Петрович

# %%
p = soup.find_all('p')
for elem in p:
    print(elem.getText())
# Out:
# Каменев Гаврил Петрович (1772-1803), казанский поэт, один из первых представителей раннего русского романтизма. Г.П. Каменев родился 3 февраля 1772 г. в Казани. Его отец, купец П.Г. Каменев, происходил из татарского княжеского рода Макуловых.
# ...

# %%
p = soup.find_all('pre')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('em')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('dd')
for elem in p:
    print(elem.getText())

# %% [markdown]
# # 16

# %%
url = google_urls[31]
print(url)
page = requests.get(url) 
print(page.encoding)
page.encoding = 'cp1251'
soup = BeautifulSoup(page.text) 
soup.find('title').getText()
# Out:
# http://www.vidania.ru/pisateli/kamenev_gavriiil_petrovich.html
# ISO-8859-1
# 'Каменев Гавриил Петрович'

# %%
p = soup.find_all('h1')
for elem in p:
    print(elem.getText())
# Out:
# Каменев Гавриил Петрович

# %%
p = soup.find_all('h2')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('p')
for elem in p:
    print(elem.getText())
# Out:
# Каменев Гавриил Петрович родился 3(14).II.1772 г. в городе Казани в старинной и богатой купеческой семье, умер там же 25.VII.(6.VIII).1803 г.
#
#
# Каменев Гавриил Петрович — поэт, переводчик.
#
#
# Отец его занимал видное общественное положение, был президентом губернского магистрата и городским головой. Гавриил Петрович получил типично дворянское воспитание в закрытом немецком пансионе Вольфинга, уже в детстве хорошо изучил немецкий и французский языки. После окончания пансиона сблизился с С. А. Москотильниковым, литератором и масоном, появившимся в Казани в 1793. Это общение, способствовало развитию поэтической деятельности Каменева, к которой он обратился, где-то, в начале 90-х гг. (самое раннее из дошедших до нас произведений Каменева датировано 1792 — стихотворная переработка четвертой песни библейской поэмы Соломона Гесснера «Авелева смерть», опубликованного в 1909). Гавриил Петрович получает доступ в «большую» столичную литературу.
#
#
# ...

# %%
p = soup.find_all('pre')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('em')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('dd')
for elem in p:
    print(elem.getText())

# %% [markdown]
# # 17

# %%
url = google_urls[32]
print(url)
page = requests.get(url) 
soup = BeautifulSoup(page.text) 
soup.find('title').getText()
# Out:
# http://russian_xviii_centure.academic.ru/350/%D0%9A%D0%B0%D0%BC%D0%B5%D0%BD%D0%B5%D0%B2_%D0%93%D0%B0%D0%B2%D1%80%D0%B8%D0%BB%D0%B0_%D0%9F%D0%B5%D1%82%D1%80%D0%BE%D0%B2%D0%B8%D1%87
# 'Каменев Гаврила Петрович - это... Что такое Каменев Гаврила Петрович?'

# %%
p = soup.find_all('h1')
for elem in p:
    print(elem.getText())
# Out:
# Каменев Гаврила Петрович

# %%
p = soup.find_all('h2')
for elem in p:
    print(elem.getText())
# Out:
# Словари и энциклопедии на Академике
#
# Словарь русского языка XVIII века

# %%
p = soup.find_all('p')
for elem in p:
    print(elem.getText())
# Out:
# Словарь русского языка XVIII века. — М:. Институт русской литературы и языка.
#    Ответственный редактор словаря – А.М. Панченко.
#    1988-1999.
#
# Список российских командиров наполеоновских и революционных войн —  …   Википедия
# Русские поэты XVIII века — Периодизация русской поэзии не совпадает в точности с границами столетий. Поэтому в список русских поэтов XVIII века включены и авторы, работавшие в самом начале XIX века, которых в первом приближении можно охарактеризовать как авторов… …   Википедия
# Второв, Николай Иванович — У этого термина существуют и другие значения, см. Второв. Николай Иванович Второв (9 (21) сентября 1818, Самара  1 (13) декабря 1865)  русский краевед, историк, этнограф, мемуарист; сын И. А. Второва. Окончил гимназию в Казани …   Википедия
# ...

# %%
p = soup.find_all('pre')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('em')
for elem in p:
    print(elem.getText())
# Out:
# С. А. Москотилъникову
# И. И. Мартынова
# И. В. Лопухин
# И. П. Тургеневу
# Н. М. Карамзиным
# И. И. Дмитриевым
# И. И. Дмитревским
# П. А. Сохацким
# М. М. Щербатова
# М. М. Хераскова
# Второв Н. Г
# Бобров Е
# Бобров Е
# Агафонов Н. Я
# Залкинд Г
# Берков П. Н
# Орлов Вл
# Giesemann
# G
# Вацуро В. Э
# Лазарчук Р. М
# Орлов П
# Suchanek L
# P. М
# . Лазарчук
# Словарь русского языка XVIII века. — М:. Институт русской литературы и языка.
#    Ответственный редактор словаря – А.М. Панченко.
#    1988-1999.

# %%
p = soup.find_all('dd')
for elem in p:
    print(elem.getText())
# Out:
# Каменев Гаврила Петрович [3 (14) II 1772, Казань – 25 или 26 II (6 или 7 VIII) 1803, там же; похоронен в Кизическом м-ре]. Принадлежал к старинному роду, который вел свое происхождение от татар. мурзы Макула, крещенного Иваном Грозным вскоре после покорения Казани. Однако прадед и дед поэта уже никакими дворянскими привилегиями не обладали и занимались торговлей. Отец К., Петр Григорьевич (1740–1776) – самый богатый из казанских купцов, владелец крепостных, президент магистрата и городской голова (1773–1775). Мать К., Татьяна Ивановна (ум. 1779), – дочь казанского купца-старообрядца И. В. Крохина, «первого вельможи» у Пугачева. Не ранее 1784 (РГИА, ф. 730, оп. 1, № 183, л. 62) осиротевшего К. поместили в пансион М. Вюльфинга, лучший в городе. Из пансиона, где К. обучался вместе с дворянскими детьми, он вынес великолепное знание нем. языка и литературы, но по-русски писал чрезвычайно безграмотно. Фр. язык, по свидетельству Н. И. Второва, К. изучил «основательно» только в «зрелых годах
# ...

# %% [markdown]
# # 18

# %%
url = google_urls[33]
print(url)
page = requests.get(url) 
soup = BeautifulSoup(page.text) 
soup.find('title').getText()
# Out:
# http://www.clubochek.ru/prose.php?id=56364
# '404 Not Found'

# %% [markdown]
# # 19

# %%
url = google_urls[36]
print(url)
page = requests.get(url) 
soup = BeautifulSoup(page.text) 
soup.find('title').getText()
# Out:
# https://poemata.ru/poets/kamenev-gavriil/
# 'Стихи Гавриила Каменева — 16 стихотворений в сборнике'

# %%
p = soup.find_all('h1')
for elem in p:
    print(elem.getText())
# Out:
# Стихи Гавриила Петровича Каменева

# %%
p = soup.find_all('h2')
for elem in p:
    print(elem.getText())
# Out:
# Топ-10 стихотворений
# Темы стихов Г. П. Каменева
# По типу
# Все стихи Гавриила Каменева списком
# Популярные поэты
# Темы стихов

# %%
p = soup.find_all('P')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('pre')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('em')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('dd')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('li')
for elem in p:
    print(elem.getText())
# Out:
#                         Русские поэты
#
#
#
#
#                         Зарубежные поэты
#
#
#
#
#                         Современные авторы
#
#
#
#
#                         Лучшие стихи
#
#
#
#
# Избранное
#
#
# Поэты
# Каменев Гавриил Петрович
#
# Expromtum (С немецкого)  •   3
#
#
# В тишине уединенной...  •   1
#
#
# Экспромт  •   1
#
#
# Сон  •
#
#
# При утренней прохладе...  •
#
#
# Мечта  •
#
#
# Вечер любезный! вечер багряный...  •
#
#
# К Пленире  •
#
#
# На Новый 1802-й год. К друзьям  •
#
#
# К П.С.Л.Р.  •
#
# 1
# 2
# любовь
# мужчина
# короткие
# грустные
# Expromtum (С немецкого)
# В тишине уединенной...
# Экспромт
# Сон
# При утренней прохладе...
# Мечта
# Вечер любезный! вечер багряный...
# К Пленире
# На Новый 1802-й год. К друзьям
# К П.С.Л.Р.
# Бури свирепством роза погибла...
# Малиновка
# Я в лесочке...
# Старик
# Кладбище
# Громвал
# Пастернак Борис Леонидович
# Михалков Сергей
# Ахматова Анна
# Белый Андрей
# Шевченко Тарас Григорьевич
# Джалиль Муса
# ...

# %% [markdown]
# # 20

# %%
url = google_urls[38]
print(url)
page = requests.get(url) 
soup = BeautifulSoup(page.text) 
soup.find('title').getText()
# Out:
# https://rustih.ru/gavriil-kamenev/
# 'Гавриил Каменев стихи: читать все стихотворения, поэмы поэта Гавриил Каменев - Поэзия на РуСтих'

# %%
p = soup.find_all('li')
for elem in p:
    print(elem.getText())
# Out:
# Русские
# Зарубежные
# Современные
# Список поэтовПоэты 18 векаЗолотой векСеребряный векСоветские поэты
# Поэты 18 века
# Золотой век
# Серебряный век
# Советские поэты
# ...

# %%
p = soup.find_all('h1')
for elem in p:
    print(elem.getText())
# Out:
# Гавриил Каменев: Стихи

# %%
p = soup.find_all('h2')
for elem in p:
    print(elem.getText())
# Out:
# Список стихотворений:
# Отзывы: 1

# %%
p = soup.find_all('p')
for elem in p:
    print(elem.getText())
# Out:
# Довольно специфическая и в то же время захватывающая поэзия. Каждый стих — как отдельная история что требует развития. Каменев действительно интересный поет. Жаль что теперь о нем мало кто знает.
# Имя
#  Комментарий
#
# Гавриил Каменев: читать популярные, лучшие, красивые стихотворения поэта классика на сайте РуСтих о любви и Родине, природе и животных, для детей и взрослых. Если вы не нашли желаемый стих, поэта или тематику, рекомендуем воспользоваться поиском вверху сайта.
# Огромная база, сборники стихов известных русских и зарубежных поэтов классиков в Антологии РуСтих | Все стихи | Карта сайта | Контакты
# ...

# %%
p = soup.find_all('pre')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('em')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('dd')
for elem in p:
    print(elem.getText())

# %% [markdown]
# # 21

# %%
url = google_urls[40]
print(url)
page = requests.get(url) 
soup = BeautifulSoup(page.text) 
soup.find('title').getText()
# Out:
# https://godliteratury.ru/projects/gavriil-kamenev-pozabyt-ya-vsey-vsele
# 'Гавриил Каменев. «Позабыт я всей вселенной» «  Год Литературы'

# %%
p = soup.find_all('h1')
for elem in p:
    print(elem.getText())
# Out:
# Гавриил Каменев. «Позабыт я всей вселенной»

# %%
p = soup.find_all('h2')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('p')
for elem in p:
    print(elem.getText())
# Out:
# Почему предтеча русских романтиков Гавриил Каменев оказался на «литературном кладбище»
#
# Текст: Олег Корякин, Казань
# Фото: wikipedia.org
# 20 марта исполнилось 245 лет со дня рождения казанского поэта Гавриила Каменева (1773—1803). Личность эта яркая и трагическая. Представитель богатого купеческого рода, бургомистр Казани, известный литератор своего времени, сгоревший от чахотки в 30 лет.
# Пушкин считал, что он «первый в России осмелился отступить от классицизма», и призывал русских романтиков «принести должную дань его памяти». Но Каменев, как это часто бывает с первопроходцами, оказался в забвении.
# Надгробие Каменева на кладбище Кизического монастыря. Конец XIX в.
# ...

# %%
p = soup.find_all('pre')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('em')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('dd')
for elem in p:
    print(elem.getText())

# %% [markdown]
# # 22

# %%
url = google_urls[42]
print(url)
page = requests.get(url) 
soup = BeautifulSoup(page.text) 
soup.find('title').getText()
# Out:
# http://history-kazan.ru/kazan-vchera-segodnya-zavtra/istoriya-v-litsakh/zhzl-kazanskaya-seriya/16851-geroj-svoego-vremeni-poet-gavriil-kamenev
# 'Герой своего времени поэт Гавриил Каменев'

# %%
p = soup.find_all('h1')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('h2')
for elem in p:
    print(elem.getText())
# Out:
# 		Герой своего времени поэт Гавриил Каменев

# %%
p = soup.find_all('p')
for elem in p:
    print(elem.getText())
# Out:
# Цитата
# Сей город, бесспорно, первый в России после Москвы, а Тверь – лучший после Петербурга; во всем видно, что Казань столица большого царства. По всей дороге прием мне был весьма ласковый и одинаковый, только здесь еще кажется градусом выше, по причине редкости для них видеть. Однако же с Ярославом, Нижним и Казанью да сбудется французская пословица, что от господского взгляду лошади разжиреют: вы уже узнаете в сенате, что я для сих городов сделала распоряжение
# Письмо А. В. ОлсуфьевуЕКАТЕРИНА II И КАЗАНЬ
# Хронограф
# 1940 – Родился Виктор Кронидович Федотов, живописец, заслуженный деятель искусств РТ, народный художник РТ
# 1809 – По указанию императора Александра I от 2 (15) марта в Казани вместо лазарета на 240 коек учрежден особый военный госпиталь на 300 больных.
#
# Фотогалерея
# ...

# %%
p = soup.find_all('pre')
for elem in p:
    print(elem.getText())

# %% [markdown]
# Тег **em** предназначен для акцентирования текста.

# %%
p = soup.find_all('em')
for elem in p:
    print(elem.getText())

# %%
p = soup.find_all('dd')
for elem in p:
    print(elem.getText())
# Out:
# 	09 сентября 2009 года

# %%
p = soup.find_all('li')
for elem in p:
    print(elem.getText())
# Out:
# Актуальная тема
# Казанские некрополи
# Афиша культурных событий
# Новая жизнь старой Казани
# В курсе событийФакты и комментарииВпечатленияНовая жизнь старой КазаниИнтересный собеседникМысли вслухСам себе писательЧитальный залНа редакционной кухнеБез комментариев
# Факты и комментарии
# Впечатления
# Новая жизнь старой Казани
# Интересный собеседник
# Мысли вслух
# Сам себе писатель
# Читальный зал
# На редакционной кухне
# Без комментариев
# Казань вчера, сегодня, завтраТочка на карте городаРетроспективаИстория в лицахЛюбовь к отеческим гробам...Пешком в историюМоя родословнаяРеспублика, в которой мы живемРоссийская историяМировая историяСпрашивайте – отвечаемРабота над ошибками
# Точка на карте города
# Ретроспектива
# История в лицах
# Любовь к отеческим гробам...
# Пешком в историю
# Моя родословная
# Республика, в которой мы живем
# Российская история
# Мировая история
# Спрашивайте – отвечаем
# Работа над ошибками
# ...

# %% [markdown]
# Тег **abbr** указывает, что последовательность символов является аббревиатурой.

# %%
p = soup.find_all('abbr')
for elem in p:
    print(elem.getText())

# %% [markdown]
# Тег **acronym** сообщает, что текст является акронимом.

# %%
p = soup.find_all('acronym')
for elem in p:
    print(elem.getText())

# %% [markdown]
# Тег **address** предназначен для хранения информации об авторе

# %%
p = soup.find_all('address')
for elem in p:
    print(elem.getText())

# %% [markdown]
# Тег **b** устанавливает жирное начертание шрифта.

# %%
p = soup.find_all('b')
for elem in p:
    print(elem.getText())
# Out:
# БИБЛИОТЕКА
# ЗАВТРАШНЕЙ
# КНИГИ
# Михаил Польский
# ОГЛАВЛЕНИЕ
#
#
# ЖИЗНЬ ОДНА*
#
# "АРБАТСТВО,
# РАСТВОРЕННОЕ В КРОВИ"
#
#
# Предисловие 2001 года
# СОДЕРЖАНИЕ КНИГИ "ЖИЗНЬ
# ОДНА":
#
# Марк Азов "АРБАТСТВО,
# РАСТВОРЕННОЕ В КРОВИ"
# Часть 1.
# Часть 2.
# Часть 3.
# Часть 4.
# *Книга издана.
# вверх

# %% [markdown]
# Тег **blockquote** предназначен для выделения длинных цитат внутри документа.

# %%
p = soup.find_all('blockquote')
for elem in p:
    print(elem.getText())
# Out:
# Моей маме Маре-Этель
#  посвящаю эту книжку

# %% [markdown]
# Тег **cite** помечает текст как цитату или сноску на другой материал.

# %%
p = soup.find_all('cite')
for elem in p:
    print(elem.getText())

# %% [markdown]
# Тег **h3** задает заголовок третьего уровня.

# %%
p = soup.find_all('h3')
for elem in p:
    print(elem.getText())

# %% [markdown]
# Тег **h4** задает заголовок четвертого уровня.

# %%
p = soup.find_all('h4')
for elem in p:
    print(elem.getText())

# %% [markdown]
# Тег **h5** задает заголовок пятого уровня.

# %%
p = soup.find_all('h5')
for elem in p:
    print(elem.getText())

# %% [markdown]
# Тег **h6** задает заголовок шестого уровня.

# %%
p = soup.find_all('h6')
for elem in p:
    print(elem.getText())

# %% [markdown]
# Тег **mark** помечает текст как выделенный.

# %%
p = soup.find_all('mark')
for elem in p:
    print(elem.getText())

# %% [markdown]
# Тег **plaintext** отображает содержимое контейнера «как есть».

# %%
p = soup.find_all('plaintext')
for elem in p:
    print(elem.getText())

# %% [markdown]
# Тег **ruby** предназначен для добавления небольшой аннотации сверху или снизу от заданного текста.

# %%
p = soup.find_all('ruby')
for elem in p:
    print(elem.getText())

# %% [markdown]
# Тег **rp** используется для вывода текста в браузерах, которые не поддерживают тег **ruby**.

# %%
p = soup.find_all('rp')
for elem in p:
    print(elem.getText())
